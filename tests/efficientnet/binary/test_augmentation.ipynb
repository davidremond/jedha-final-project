# %%
# !pip install mlflow
# Out:
# Collecting mlflow
#   Downloading mlflow-2.20.0-py3-none-any.whl.metadata (30 kB)
# Collecting mlflow-skinny==2.20.0 (from mlflow)
#   Downloading mlflow_skinny-2.20.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: Flask<4 in /usr/local/lib/python3.10/dist-packages (from mlflow) (3.1.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in /usr/local/lib/python3.10/dist-packages (from mlflow) (3.1.4)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Downloading alembic-1.14.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.10/dist-packages (from mlflow) (3.7)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.10/dist-packages (from mlflow) (3.8.0)
# Requirement already satisfied: numpy<3 in /usr/local/lib/python3.10/dist-packages (from mlflow) (1.26.4)
# Requirement already satisfied: pandas<3 in /usr/local/lib/python3.10/dist-packages (from mlflow) (2.2.2)
# Requirement already satisfied: pyarrow<19,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from mlflow) (17.0.0)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.10/dist-packages (from mlflow) (1.6.0)
# Requirement already satisfied: scipy<2 in /usr/local/lib/python3.10/dist-packages (from mlflow) (1.13.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from mlflow) (2.0.36)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.20.0->mlflow) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.20.0->mlflow) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.20.0->mlflow) (3.1.0)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==2.20.0->mlflow)
#   Downloading databricks_sdk-0.41.0-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.20.0->mlflow) (3.1.43)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.20.0->mlflow) (8.5.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.20.0->mlflow) (1.29.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.20.0->mlflow) (1.29.0)
# Requirement already satisfied: packaging<25 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.20.0->mlflow) (24.2)
# Requirement already satisfied: protobuf<6,>=3.12.0 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.20.0->mlflow) (4.25.5)
# Requirement already satisfied: pydantic<3,>=1.0 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.20.0->mlflow) (2.10.3)
# Requirement already satisfied: pyyaml<7,>=5.1 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.20.0->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.20.0->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.20.0->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from mlflow-skinny==2.20.0->mlflow) (4.12.2)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Downloading Mako-1.3.8-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from docker<8,>=4.0.0->mlflow) (2.2.3)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.10/dist-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.10/dist-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.10/dist-packages (from Flask<4->mlflow) (1.9.0)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from graphene<4->mlflow) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2<4,>=2.11->mlflow) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow) (3.2.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3->mlflow) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3->mlflow) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2->mlflow) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.1.1)
# Requirement already satisfied: google-auth~=2.0 in /usr/local/lib/python3.10/dist-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.0->mlflow) (2.27.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.20.0->mlflow) (4.0.11)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.20.0->mlflow) (3.21.0)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.0->mlflow) (1.2.15)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.20.0->mlflow) (0.50b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.0->mlflow-skinny==2.20.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.0->mlflow-skinny==2.20.0->mlflow) (2.27.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==2.20.0->mlflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==2.20.0->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==2.20.0->mlflow) (2024.12.14)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.0->mlflow) (1.17.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.20.0->mlflow) (5.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.0->mlflow) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.0->mlflow) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.0->mlflow) (0.6.1)
# Downloading mlflow-2.20.0-py3-none-any.whl (28.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.3/28.3 MB 64.0 MB/s eta 0:00:00
# Downloading mlflow_skinny-2.20.0-py3-none-any.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 103.7 MB/s eta 0:00:00
# Downloading alembic-1.14.1-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 22.4 MB/s eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 13.0 MB/s eta 0:00:00
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 11.4 MB/s eta 0:00:00
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 8.7 MB/s eta 0:00:00
# Downloading databricks_sdk-0.41.0-py3-none-any.whl (637 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 637.5/637.5 kB 49.2 MB/s eta 0:00:00
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 21.4 MB/s eta 0:00:00
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading Mako-1.3.8-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 7.1 MB/s eta 0:00:00
# Installing collected packages: Mako, gunicorn, graphql-core, graphql-relay, docker, alembic, graphene, databricks-sdk, mlflow-skinny, mlflow
# Successfully installed Mako-1.3.8 alembic-1.14.1 databricks-sdk-0.41.0 docker-7.1.0 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 gunicorn-23.0.0 mlflow-2.20.0 mlflow-skinny-2.20.0

# %%
import kagglehub
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import os
import random
import shutil
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mlflow
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import shutil
import mlflow

# %%
if os.path.exists('data'):
  shutil.rmtree('data')

# %%
# !kaggle datasets download -d ghostbat101/lung-x-ray-image-clinical-text-dataset -p data
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ghostbat101/lung-x-ray-image-clinical-text-dataset
# License(s): MIT
# Downloading lung-x-ray-image-clinical-text-dataset.zip to data
# 100% 1.33G/1.33G [01:05<00:00, 23.1MB/s]
# 100% 1.33G/1.33G [01:05<00:00, 21.8MB/s]

# %%
# !unzip -n data/lung-x-ray-image-clinical-text-dataset.zip -d data
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_45915.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4592.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_45950.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_45951.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_45952.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_45953.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_45956.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_45957.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_45961.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_45964.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_45967.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4597.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_45970.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_45978.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_45993.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46001.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46007.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46033.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46041.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4605.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46054.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46065.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46073.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46076.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46080.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46082.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4610.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46113.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46119.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4614.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46143.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46146.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46156.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46168.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46185.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46188.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46192.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46205.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46218.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46227.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46238.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46247.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46248.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46258.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46279.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4628.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46288.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46290.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46291.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46297.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46298.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46308.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4631.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46318.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46321.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46339.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46340.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4635.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46351.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46355.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4636.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46364.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46382.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46385.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46394.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46403.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46405.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46411.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46421.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46439.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46452.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46458.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46465.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46470.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46476.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46477.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46486.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46492.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46522.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46524.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46528.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46546.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46555.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46564.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46570.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46577.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46581.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_466.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46618.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46623.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4664.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46651.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46675.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46682.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46689.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46691.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46709.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46710.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46712.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46717.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46724.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46726.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46734.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46735.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46736.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4674.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46744.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46752.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46757.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46784.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46786.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46790.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46802.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46813.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46818.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4683.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46851.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46855.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46858.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46877.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4689.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46892.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_469.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46902.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46907.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46912.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46916.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46919.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4692.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46923.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46953.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46956.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46971.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46985.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_46989.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_470.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47005.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47011.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47013.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47017.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47018.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4702.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47035.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4704.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47060.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47064.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4708.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47086.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47107.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47114.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47117.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47118.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47132.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47133.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47136.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47152.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47154.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47157.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47166.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47178.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47185.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47189.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47192.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47204.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47212.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4722.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47232.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47238.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47240.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47243.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47258.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47266.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47267.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47270.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47273.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47274.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4729.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47300.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47313.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47319.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47322.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47325.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4733.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47339.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47343.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47350.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47352.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47360.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47372.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47373.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47375.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47383.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47408.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47409.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47414.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47429.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47435.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47463.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47467.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47470.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47499.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47500.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47503.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47506.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47509.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47514.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47529.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4753.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47537.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4754.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47544.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47554.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47558.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47569.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4757.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47580.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47584.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47597.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47609.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47610.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47619.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4762.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47649.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47659.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47673.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47675.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4769.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47691.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4770.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47727.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47738.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47742.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4776.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47766.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47768.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47773.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47778.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47782.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47787.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47795.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47800.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47803.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47822.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47828.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47831.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47847.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47853.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47854.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47858.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47860.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47871.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47880.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47889.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4789.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47899.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47911.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47918.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47926.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47929.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47935.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47942.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47943.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47948.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47958.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47977.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47988.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47989.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47991.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_47992.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48003.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48013.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48016.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48037.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48043.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48055.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48068.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48080.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48084.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48092.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48093.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48098.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48101.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48103.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48104.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48112.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48113.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48118.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48119.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48123.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48126.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4813.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48132.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48133.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4814.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48142.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48144.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48147.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48148.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48160.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48163.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4817.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48173.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48176.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4819.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48191.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48192.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4820.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48202.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48214.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48252.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48260.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4827.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48274.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4828.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48281.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48282.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48299.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4831.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48312.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48314.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48320.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48329.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4834.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48342.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48354.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48355.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48366.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48371.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48378.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48380.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48399.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4840.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48426.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48430.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48431.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48435.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48438.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48443.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48444.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48446.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48451.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48454.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48455.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48457.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48471.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48479.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4848.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48481.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48482.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48487.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48495.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48501.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48502.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48520.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48522.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48527.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48529.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48540.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48541.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48548.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4855.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48554.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48555.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48558.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48559.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48560.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48568.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4859.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48593.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48598.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48600.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4861.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48611.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48617.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48622.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48630.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48632.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48647.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4867.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48675.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48692.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48696.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48705.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48725.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48749.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48755.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48757.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48765.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48774.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48785.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48786.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48791.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48793.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48796.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48797.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48807.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48816.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48817.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48827.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48845.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48856.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48859.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48863.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48872.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48881.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48886.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48889.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48890.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48907.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48912.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48918.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48920.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4894.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48948.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48951.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48954.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48969.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48972.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48977.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48978.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48987.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_48990.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4900.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49002.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49011.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49020.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49021.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49023.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49032.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49045.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49055.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49063.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49066.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49069.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49073.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49083.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49094.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49095.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49097.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4910.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49106.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49117.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49158.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49164.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49175.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49184.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49197.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4921.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49213.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49216.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49218.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4922.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49226.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49230.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49236.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49237.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49239.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49249.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49250.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4926.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49266.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49272.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49284.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49286.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4929.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49290.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49291.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49295.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_493.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49305.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49322.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49331.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49333.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49352.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49366.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49378.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49388.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49391.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49392.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49393.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49396.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49408.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4941.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49418.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49426.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49427.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49428.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49437.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49439.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49443.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49458.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49465.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49466.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49485.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49498.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49499.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49523.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49529.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49537.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49542.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49547.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49551.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49561.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49564.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49581.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49590.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_4960.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49600.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49601.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49617.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49620.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49638.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49643.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49653.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49657.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49662.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49687.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49694.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49697.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_49704.jpg
# ...
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8638.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8640.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8642.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8643.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8645.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8677.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8678.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8683.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8685.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8691.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8731.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8736.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8749.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8753.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8762.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8766.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8776.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8778.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8789.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8801.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8806.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8810.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8817.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8826.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8843.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8849.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8851.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8852.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_887.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8870.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8876.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_888.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8884.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_889.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8894.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8895.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_890.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8907.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8921.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8925.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8931.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8935.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8937.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8941.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8950.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8953.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8967.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_897.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8979.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_8989.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9000.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9024.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9031.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9037.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9040.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9044.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9049.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9051.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9053.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9056.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9059.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9066.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9069.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9085.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9097.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9099.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9107.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9108.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_911.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9110.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9116.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9119.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9138.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_914.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9142.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9156.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9161.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9168.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9177.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9182.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9191.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9193.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9197.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9198.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_920.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9201.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9207.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9217.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_923.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9230.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9256.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9259.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9262.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9274.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9284.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9287.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9296.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9306.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9312.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9317.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9318.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9331.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_934.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9359.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9373.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9374.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9385.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9398.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9399.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9404.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9408.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9414.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9415.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9420.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9435.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9449.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9456.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_948.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9492.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9499.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9504.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9518.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9521.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9528.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9532.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9537.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9543.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9544.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9548.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_955.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9565.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9566.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_958.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9585.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9588.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9590.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9604.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9609.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9640.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9649.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9657.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9679.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9684.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9688.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9705.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9711.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9718.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_973.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9743.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9751.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9755.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9761.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9773.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9781.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9809.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9812.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9817.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9818.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9821.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_984.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9844.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9852.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9856.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9857.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9858.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_987.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9875.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9920.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9922.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9941.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_996.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9966.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9982.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9984.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9992.jpg
#   inflating: data/Merged Data (image+text)/Obstructive Pulmonary Diseases/image_9997.jpg

# %% [markdown]
# On remplace les espaces par _ dans les noms des dossiers et fichiers

# %%
def replace_spaces_with_underscores(directory):
    for root, dirs, files in os.walk(directory, topdown=False):
        for name in dirs:
            new_name = name.replace(' ', '_')
            if new_name != name:
                old_path = os.path.join(root, name)
                new_path = os.path.join(root, new_name)
                shutil.move(old_path, new_path)
                print(f"Renamed: {old_path} -> {new_path}")

replace_spaces_with_underscores('data')
# Out:
# Renamed: data/Merged Data (image+text)/Higher Density -> data/Merged Data (image+text)/Higher_Density
# Renamed: data/Merged Data (image+text)/Obstructive Pulmonary Diseases -> data/Merged Data (image+text)/Obstructive_Pulmonary_Diseases
# Renamed: data/Merged Data (image+text)/Mediastinal Changes -> data/Merged Data (image+text)/Mediastinal_Changes
# Renamed: data/Merged Data (image+text)/Lower Density -> data/Merged Data (image+text)/Lower_Density
# Renamed: data/Merged Data (image+text)/Encapsulated Lesions -> data/Merged Data (image+text)/Encapsulated_Lesions
# Renamed: data/Merged Data (image+text)/Degenerative Infectious Diseases -> data/Merged Data (image+text)/Degenerative_Infectious_Diseases
# Renamed: data/Merged Data (image+text)/Chest Changes -> data/Merged Data (image+text)/Chest_Changes
# Renamed: data/Main dataset/Higher Density -> data/Main dataset/Higher_Density
# Renamed: data/Main dataset/Obstructive Pulmonary Diseases -> data/Main dataset/Obstructive_Pulmonary_Diseases
# Renamed: data/Main dataset/Mediastinal Changes -> data/Main dataset/Mediastinal_Changes
# Renamed: data/Main dataset/Lower Density -> data/Main dataset/Lower_Density
# Renamed: data/Main dataset/Encapsulated Lesions -> data/Main dataset/Encapsulated_Lesions
# Renamed: data/Main dataset/Degenerative Infectious Diseases -> data/Main dataset/Degenerative_Infectious_Diseases
# Renamed: data/Main dataset/Chest Changes -> data/Main dataset/Chest_Changes
# Renamed: data/Merged Data (image+text) -> data/Merged_Data_(image+text)
# Renamed: data/Main dataset -> data/Main_dataset

# %% [markdown]
# On met de côté 20 % des données pour le test

# %%
# Chemin vers le dataset principal
source_dir = "data/Main_dataset"

# Chemin vers le dossier où les 20% seront stockés
test_dir = "data/Test_dataset"

# Fraction des données à extraire
test_split = 0.2

# Définir un seed pour rendre le tirage aléatoire reproductible
random.seed(42)

# Créer le dossier de sortie
os.makedirs(test_dir, exist_ok=True)

# Parcourir chaque classe (dossier dans le dataset principal)
for class_name in os.listdir(source_dir):
    class_path = os.path.join(source_dir, class_name)
    if os.path.isdir(class_path):  # Vérifier que c'est un dossier
        # Lister tous les fichiers de la classe
        images = os.listdir(class_path)

        # Mélanger les fichiers aléatoirement
        random.shuffle(images)

        # Calculer le nombre de fichiers à déplacer
        num_test_files = int(len(images) * test_split)
        test_files = images[:num_test_files]

        # Créer un dossier pour cette classe dans le dossier de test
        class_test_dir = os.path.join(test_dir, class_name)
        os.makedirs(class_test_dir, exist_ok=True)

        # Déplacer les fichiers sélectionnés
        for img in test_files:
            src_path = os.path.join(class_path, img)
            dest_path = os.path.join(class_test_dir, img)
            shutil.move(src_path, dest_path)

print(f"20% des données ont été déplacées vers le dossier '{test_dir}'")
# Out:
# 20% des données ont été déplacées vers le dossier 'data/Test_dataset'

# %% [markdown]
# # Creation d'un sample avec 20 % des données : Main dataset Sample

# %%
# Chemin vers le dataset principal
source_dir = "data/Main_dataset"

# Chemin vers le dossier où les 20% seront copiés
test_dir = "data/Main_dataset_Sample"

# Fraction des données à extraire
main_sample = 0.2

# Définir un seed pour rendre le tirage aléatoire reproductible
random.seed(42)

# Créer le dossier de sortie pour le dataset de test
os.makedirs(test_dir, exist_ok=True)

# Parcourir chaque classe (dossier dans le dataset principal)
for class_name in os.listdir(source_dir):
    class_path = os.path.join(source_dir, class_name)

    if os.path.isdir(class_path):  # Vérifier que c'est un dossier
        # Lister tous les fichiers de la classe
        images = os.listdir(class_path)

        # Mélanger les fichiers aléatoirement
        random.shuffle(images)

        # Calculer le nombre de fichiers à dupliquer
        num_sample_files = int(len(images) * main_sample)  # Correction du nom de la variable
        sample_files = images[:num_sample_files]

        # Créer un dossier pour cette classe dans le dossier de test
        class_sample_dir = os.path.join(test_dir, class_name)
        os.makedirs(class_sample_dir, exist_ok=True)  # Correction du nom du dossier

        # Dupliquer les fichiers sélectionnés dans le dossier de test
        for img in sample_files:  # Correction de la variable test_files en sample_files
            src_path = os.path.join(class_path, img)
            dest_path = os.path.join(class_sample_dir, img)
            shutil.copy(src_path, dest_path)  # Utilisation de shutil.copy() pour dupliquer

print("Les 20% des données ont été dupliquées dans le répertoire Main dataset Sample.")
# Out:
# Les 20% des données ont été dupliquées dans le répertoire Main dataset Sample.

# %% [markdown]
# # Transformation en binaire : main dataset sample binaire et en multiclasse malade : main dataset sample multiclasse

# %%
# Chemin vers le dataset principal
source_dir = "data/Main_dataset_Sample"

# Chemin vers le nouveau dataset binaire
binary_sample_dir = "data/Main_dataset_Sample_Binaire"


# Créer les répertoires de sortie pour les classes "Normal" et "Malades"
os.makedirs(binary_sample_dir, exist_ok=True)
normal_dir = os.path.join(binary_sample_dir, "Normal")
malades_dir = os.path.join(binary_sample_dir, "Malades")
os.makedirs(normal_dir, exist_ok=True)
os.makedirs(malades_dir, exist_ok=True)

# Liste des classes malades
malades_classes = ['Chest_Changes', 'Degenerative_Infectious_Diseases', 'Encapsulated_Lesions',
                    'Higher_Density', 'Lower_Density', 'Mediastinal_Changes', 'Obstructive_Pulmonary_Diseases']

# Parcourir chaque classe (dossier dans le dataset principal)
for class_name in os.listdir(source_dir):
    class_path = os.path.join(source_dir, class_name)

    if os.path.isdir(class_path):  # Vérifier que c'est un dossier
        # Lister tous les fichiers de la classe
        images = os.listdir(class_path)

        # Mélanger les fichiers aléatoirement
        random.shuffle(images)

        # Calculer le nombre de fichiers à dupliquer
        num_sample_files = int(len(images) * main_sample)
        sample_files = images[:num_sample_files]

        if class_name == 'Normal':
            # Créer le dossier pour la classe "Normal"
            for img in sample_files:
                src_path = os.path.join(class_path, img)
                dest_path = os.path.join(normal_dir, img)
                shutil.copy(src_path, dest_path)  # Copier l'image dans le dossier "Normal"

        elif class_name in malades_classes:
            # Créer le dossier pour les classes malades
            for img in sample_files:
                src_path = os.path.join(class_path, img)
                dest_path = os.path.join(malades_dir, img)
                shutil.copy(src_path, dest_path)  # Copier l'image dans le dossier "Malades"

print("Les données ont été dupliquées dans le répertoire Main dataset Sample Binaire avec les classes 'Normal' et 'Malades'.")
# Out:
# Les données ont été dupliquées dans le répertoire Main dataset Sample Binaire avec les classes 'Normal' et 'Malades'.

# %%
# Chemin vers le dataset principal
source_dir = "data/Main_dataset_Sample"

# Chemin vers le nouveau dataset binaire
binary_sample_dir = "data/Main_dataset_Sample_Binaire"

# Chemin vers le nouveau dataset multiclasse
multiclass_sample_dir = "data/Main_dataset_Sample_Multiclasse"

# Créer les répertoires de sortie pour les classes "Normal" et "Malades"
os.makedirs(binary_sample_dir, exist_ok=True)
normal_dir = os.path.join(binary_sample_dir, "Normal")
malades_dir = os.path.join(binary_sample_dir, "Malades")
os.makedirs(normal_dir, exist_ok=True)
os.makedirs(malades_dir, exist_ok=True)

# Créer le répertoire de sortie pour le dataset multiclasse
os.makedirs(multiclass_sample_dir, exist_ok=True)

# Liste des classes malades
malades_classes = ['Chest_Changes', 'Degenerative_Infectious_Diseases', 'Encapsulated_Lesions',
                   'Higher_Density', 'Lower_Density', 'Mediastinal_Changes', 'Obstructive_Pulmonary_Diseases']

# Parcourir chaque classe (dossier dans le dataset principal)
for class_name in os.listdir(source_dir):
    class_path = os.path.join(source_dir, class_name)

    if os.path.isdir(class_path):  # Vérifier que c'est un dossier
        # Lister tous les fichiers de la classe
        images = os.listdir(class_path)

        # Mélanger les fichiers aléatoirement
        random.shuffle(images)

        # Calculer le nombre de fichiers à dupliquer
        num_sample_files = int(len(images) * main_sample)
        sample_files = images[:num_sample_files]

        # Gestion pour le dataset binaire
        if class_name == 'Normal':
            for img in sample_files:
                src_path = os.path.join(class_path, img)
                dest_path = os.path.join(normal_dir, img)
                shutil.copy(src_path, dest_path)  # Copier l'image dans le dossier "Normal"

        elif class_name in malades_classes:
            for img in sample_files:
                src_path = os.path.join(class_path, img)
                dest_path = os.path.join(malades_dir, img)
                shutil.copy(src_path, dest_path)  # Copier l'image dans le dossier "Malades"

        # Gestion pour le dataset multiclasse
        multiclass_dir = os.path.join(multiclass_sample_dir, class_name)
        os.makedirs(multiclass_dir, exist_ok=True)  # Créer un sous-dossier pour chaque classe
        for img in sample_files:
            src_path = os.path.join(class_path, img)
            dest_path = os.path.join(multiclass_dir, img)
            shutil.copy(src_path, dest_path)  # Copier l'image dans son dossier de classe

print("Les données ont été dupliquées :")
print("- Dans le répertoire Main_dataset_Sample_Binaire avec les classes 'Normal' et 'Malades'.")
print("- Dans le répertoire Main_dataset_Sample_Multiclasse avec les sous-dossiers pour chaque classe.")
# Out:
# Les données ont été dupliquées :
# - Dans le répertoire Main_dataset_Sample_Binaire avec les classes 'Normal' et 'Malades'.
# - Dans le répertoire Main_dataset_Sample_Multiclasse avec les sous-dossiers pour chaque classe.

# %%
ratio_malade = 0.5

# Chemin vers le dataset principal
source_dir = "data/Main_dataset"

# Chemin vers le nouveau dataset binaire
binary_sample_dir = "data/Main_dataset_Sample_Binaire_With_Ratio"

# Créer les répertoires de sortie pour les classes "Normal" et "Malades"
os.makedirs(binary_sample_dir, exist_ok=True)
normal_dir = os.path.join(binary_sample_dir, "Normal")
malades_dir = os.path.join(binary_sample_dir, "Malades")
os.makedirs(normal_dir, exist_ok=True)
os.makedirs(malades_dir, exist_ok=True)

# Créer le répertoire de sortie pour le dataset multiclasse
os.makedirs(multiclass_sample_dir, exist_ok=True)

# Liste des classes malades
malades_classes = ['Chest_Changes', 'Degenerative_Infectious_Diseases', 'Encapsulated_Lesions',
                   'Higher_Density', 'Lower_Density', 'Mediastinal_Changes', 'Obstructive_Pulmonary_Diseases']

normal_classes = ['Normal']

normal_image_count = int((1- ratio_malade) * len(os.listdir(os.path.join(source_dir, normal_classes[0]))))
print(normal_image_count)
malades_image_count = int(ratio_malade * len(os.listdir(os.path.join(source_dir, normal_classes[0]))))
print(malades_image_count)

for class_name in normal_classes:
  class_path = os.path.join(source_dir, class_name)
  images = os.listdir(class_path)
  random.shuffle(images)
  num_sample_files = int(normal_image_count / len(normal_classes))
  sample_files = images[:num_sample_files]
  for img in sample_files:
    src_path = os.path.join(class_path, img)
    dest_path = os.path.join(normal_dir, img)
    shutil.copy(src_path, dest_path)

for class_name in malades_classes:
  class_path = os.path.join(source_dir, class_name)
  images = os.listdir(class_path)
  random.shuffle(images)
  num_sample_files = int(malades_image_count / len(malades_classes))
  sample_files = images[:num_sample_files]
  for img in sample_files:
    src_path = os.path.join(class_path, img)
    dest_path = os.path.join(malades_dir, img)
    shutil.copy(src_path, dest_path)

print("Les données ont été dupliquées :")
print(f"- Dans le répertoire {binary_sample_dir} avec les classes 'Normal' et 'Malades'.")
# Out:
# 4000
# 4000
# Les données ont été dupliquées :
# - Dans le répertoire data/Main_dataset_Sample_Binaire_With_Ratio avec les classes 'Normal' et 'Malades'.

# %% [markdown]
# # Démarrage du tracking MLFLOW

# %%
MLFLOW_SERVER_URI = 'https://david-rem-jedha-final-project-mlops.hf.space'
EXPERIMENT_NAME = 'binary' # 'binary' ou 'multi'
TRAINER = 'david' # Le prénom de la personne qui a exécuté l'entrainement
MODEL_TYPE = 'baseline_with_augmentation' # Le type de modèle utilisé

mlflow.set_tracking_uri(MLFLOW_SERVER_URI)
mlflow.set_experiment(EXPERIMENT_NAME)
mlflow.tensorflow.autolog()

experiment = mlflow.get_experiment_by_name(EXPERIMENT_NAME)
mlflow.start_run(experiment_id = experiment.experiment_id)
# Out:
# <ActiveRun: >

# %% [markdown]
# # Preprocessing

# %%
# Configuration de l'ImageDataGenerator avec preprocessing_function
img_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,  # Normalisation des pixels
    #preprocessing_function=preprocess_grayscale_to_rgb,  # Fonction de conversion des cqnaux
    validation_split=0.2,  # Fraction pour la validation
    #rotation_range=90,
    #brightness_range=(0.5,1),
    #shear_range=0.2,
    #zoom_range=0.2,
    #channel_shift_range=0.2,
    #horizontal_flip=True,
    #vertical_flip=True
)

# %%
# Chargement des ensembles
BATCH_SIZE = 64
img_size = (128,128)
seed = 42

# %%
# Chargement des données  de train avec flow_from_directory
img_generator_flow_train = img_generator.flow_from_directory(
    directory="data/Main_dataset_Sample_Binaire_With_Ratio",  # chemin vers les données
    target_size=img_size,    # taille des images
    batch_size=BATCH_SIZE,
    shuffle=True,
    color_mode="grayscale",    # pour charger les images en niveaux de gris
    #color_mode="rgb",    # pour charger les images en niveaux de gris
    #class_mode="categorical",  # Pour une classification multi-classes
    subset="training",
    class_mode='binary',
    seed = seed
    )
# Out:
# Found 7302 images belonging to 2 classes.

# %%
# Chargement des données  de validation avec flow_from_directory
img_generator_flow_valid = img_generator.flow_from_directory(
    directory="data/Main_dataset_Sample_Binaire_With_Ratio",
    target_size=img_size,
    batch_size=BATCH_SIZE,
    shuffle=False,
    #color_mode="rgb",
    color_mode="grayscale",
    subset="validation",
    #class_mode="categorical",
    #class_mode='sparse',
    class_mode='binary',
    seed= seed
    )
# Out:
# Found 1824 images belonging to 2 classes.

# %% [markdown]
# # Modèle

# %%
CLASSES = 1

# %%
base_model = tf.keras.applications.EfficientNetB0(
    input_shape=(128, 128, 3),
    include_top=False,  # On enlève la tête de classification
    weights="imagenet"  # Poids pré-entraînés sur ImageNet
)

# %%
base_model.trainable = False

# %%
model = tf.keras.Sequential([
    base_model,  # Modèle EfficientNet
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(128, activation='relu'),  # Couche dense
    tf.keras.layers.Dropout(0.3),  # Régularisation
    tf.keras.layers.Dense(1, activation='sigmoid')  # Classification binaire
])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ efficientnetb0 (Functional)          │ (None, 4, 4, 1280)          │       4,049,571 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_2           │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │         163,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,213,668 (16.07 MB)
#  Trainable params: 164,097 (641.00 KB)
#  Non-trainable params: 4,049,571 (15.45 MB)

# %% [markdown]
# # Entrainement

# %%
# Let's create a learning rate schedule to decrease the learning rate as we train the model.
initial_learning_rate = 0.001

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=1000,
    decay_rate=0.96,
    staircase=True)

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='accuracy', factor=0.2,
                              patience=5, min_lr=0.001)

# %%
# Créer un optimiseur avec le planning du taux d'apprentissage
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

# Compiler le modèle
model.compile(
    optimizer=optimizer,
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
# Définir un callback d'early stopping
early_stopping = EarlyStopping(
    monitor='val_loss',  # Surveiller la perte de validation
    patience=3,          # Nombre d'époques sans amélioration avant d'arrêter
    restore_best_weights=True  # Rétablir les poids du meilleur modèle
)

# %%
class_indices = img_generator_flow_train.class_indices
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(list(class_indices.values())),
    y=img_generator_flow_train.classes
)
class_weights = dict(enumerate(class_weights))

# %%
class_weights
# Out:
# {0: 0.9628164556962026, 1: 1.0401709401709403}

# %%
EPOCHS = 20

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint(
    filepath='best_model.keras',  # Save path
    monitor='accuracy',        # Ensure correct metric name
    save_best_only=True,       # Save only the best model
    mode='max',                # 'max' for accuracy, 'min' for loss
    verbose=1
)

# %%
# Entraîner le modèle avec early stopping
history = model.fit(
    #rgb_train_generator,
    img_generator_flow_train,
    validation_data=img_generator_flow_valid , #rgb_val_generator,
    epochs=EPOCHS ,  # Plus d'époques pour laisser l'early stopping décider
    #steps_per_epoch=len(img_generator_flow_train),
    #validation_steps=len(img_generator_flow_valid),
    #callbacks=[early_stopping],
    class_weight= class_weights,
    #callbacks=[checkpoint]
    #callbacks = [reduce_lr]
)
# Out:
# 2025/01/27 10:37:29 WARNING mlflow.tensorflow: Unrecognized dataset type <class 'keras.src.legacy.preprocessing.image.DirectoryIterator'>. Dataset logging skipped.
# 2025/01/27 10:37:29 WARNING mlflow.tensorflow: Unrecognized dataset type <class 'keras.src.legacy.preprocessing.image.DirectoryIterator'>. Dataset logging skipped.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 113/115 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.4891 - loss: 0.7064
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 51s 297ms/step - accuracy: 0.4893 - loss: 0.7062 - val_accuracy: 0.5192 - val_loss: 0.6929
# Epoch 2/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.5013 - loss: 0.6932 - val_accuracy: 0.4808 - val_loss: 0.6946
# Epoch 3/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.4999 - loss: 0.6927 - val_accuracy: 0.5192 - val_loss: 0.6930
# Epoch 4/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.5220 - loss: 0.6929 - val_accuracy: 0.5192 - val_loss: 0.6930
# Epoch 5/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.5113 - loss: 0.6939 - val_accuracy: 0.5192 - val_loss: 0.6929
# Epoch 6/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - accuracy: 0.5085 - loss: 0.6933 - val_accuracy: 0.5192 - val_loss: 0.6929
# Epoch 7/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.5263 - loss: 0.6927 - val_accuracy: 0.5192 - val_loss: 0.6929
# Epoch 8/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.5240 - loss: 0.6929 - val_accuracy: 0.5192 - val_loss: 0.6931
# Epoch 9/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.5295 - loss: 0.6926 - val_accuracy: 0.5192 - val_loss: 0.6930
# Epoch 10/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.4877 - loss: 0.6937 - val_accuracy: 0.5192 - val_loss: 0.6931
# Epoch 11/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.5176 - loss: 0.6932 - val_accuracy: 0.5192 - val_loss: 0.6931
# Epoch 12/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.5182 - loss: 0.6932 - val_accuracy: 0.5192 - val_loss: 0.6931
# Epoch 13/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - accuracy: 0.4818 - loss: 0.6935 - val_accuracy: 0.4808 - val_loss: 0.6932
# Epoch 14/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.4872 - loss: 0.6928 - val_accuracy: 0.4808 - val_loss: 0.6932
# Epoch 15/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.4910 - loss: 0.6937 - val_accuracy: 0.4808 - val_loss: 0.6932
# Epoch 16/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.4842 - loss: 0.6934 - val_accuracy: 0.4808 - val_loss: 0.6932
# Epoch 17/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.5001 - loss: 0.6924 - val_accuracy: 0.4808 - val_loss: 0.6932
# Epoch 18/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.4931 - loss: 0.6932 - val_accuracy: 0.5192 - val_loss: 0.6931
# Epoch 19/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.5199 - loss: 0.6931 - val_accuracy: 0.5192 - val_loss: 0.6931
# Epoch 20/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - accuracy: 0.5214 - loss: 0.6930 - val_accuracy: 0.4808 - val_loss: 0.6932
# 2025/01/27 10:40:22 WARNING mlflow.tensorflow: Failed to infer model signature: could not sample data to infer model signature: '>=' not supported between instances of 'slice' and 'int'
# 2025/01/27 10:40:22 WARNING mlflow.tensorflow: You are saving a TensorFlow Core model or Keras model without a signature. Inference with mlflow.pyfunc.spark_udf() will not work unless the model's pyfunc representation accepts pandas DataFrames as inference inputs.
# 2025/01/27 10:40:31 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %% [markdown]
# # Sauvegarde du tracking MLFLOW

# %%
mlflow.log_param("trainer", TRAINER)
mlflow.log_param("epochs", EPOCHS)
mlflow.log_param("model_type", MODEL_TYPE)

# Sauvegarde du modèle
mlflow.keras.log_model(model, "model")

# Sauvegarde des métriques par époque
history = model.history
for epoch in range(len(history.history['loss'])):
    mlflow.log_metric('loss', history.history['loss'][epoch], step=epoch)
for epoch in range(len(history.history['accuracy'])):
    mlflow.log_metric('accuracy', history.history['accuracy'][epoch], step=epoch)
for epoch in range(len(history.history['val_loss'])):
    mlflow.log_metric('val_loss', history.history['val_loss'][epoch], step=epoch)
for epoch in range(len(history.history['val_accuracy'])):
    mlflow.log_metric('val_accuracy', history.history['val_accuracy'][epoch], step=epoch)
# Out:
# 2025/01/27 10:40:41 WARNING mlflow.keras.save: You are saving a Keras model without specifying model signature.
# 2025/01/27 10:40:51 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
predictions = model.predict(img_generator_flow_valid)
y_pred = np.argmax(predictions, axis=1)
y_true = img_generator_flow_valid.classes
# Out:
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a6fc82c0af0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 12s 241ms/step

# %%
report = classification_report(y_pred, y_true)
with open("classification_report.txt", "w") as file:
    file.write(report)
mlflow.log_artifact('classification_report.txt', artifact_path="model")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
report = classification_report(y_true, y_pred, output_dict=True)
mlflow.log_metric('global_accuracy', report['accuracy'])
mlflow.log_metric('macro_avg_precision', report['macro avg']['precision'])
mlflow.log_metric('macro_avg_recall', report['macro avg']['recall'])
mlflow.log_metric('macro_avg_f1_score', report['macro avg']['f1-score'])
mlflow.log_metric('macro_avg_support', report['macro avg']['support'])
mlflow.log_metric('weighted_avg_precision', report['weighted avg']['precision'])
mlflow.log_metric('weighted_avg_recall', report['weighted avg']['recall'])
mlflow.log_metric('weighted_avg_f1_score', report['weighted avg']['f1-score'])
mlflow.log_metric('weighted_avg_support', report['weighted avg']['support'])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
for class_mesure in list(report.items())[:CLASSES]:
    for m_name, m_value in class_mesure[1].items():
        mlflow.log_metric(m_name, m_value, step=int(class_mesure[0]))

# %%
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=img_generator_flow_valid.class_indices.keys())
disp.plot()
plt.title("Matrice de Confusion")
plt.savefig("confusion_matrix.png")
mlflow.log_artifact("confusion_matrix.png", artifact_path='model')

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc

seuils = np.arange(0.0, 1.0, 0.01)

# Fonction pour calculer la F1-score pour un seuil donné
def calculer_f1_score(y_true, y_pred_prob, seuil):
    y_pred = (y_pred_prob >= seuil).astype(int)
    return f1_score(y_true, y_pred)

# Trouver le seuil qui maximise la F1-score
f1_scores = [calculer_f1_score(y_true, y_pred, seuil) for seuil in seuils]
seuil_optimal = seuils[np.argmax(f1_scores)]

print("Seuil optimal :", seuil_optimal)
print("F1-score pour le seuil optimal :", max(f1_scores))
mlflow.log_metric("optimal_threshold", seuil_optimal)
mlflow.log_metric("optimal_f1_score", max(f1_scores))
# Out:
# Seuil optimal : 0.0
# F1-score pour le seuil optimal : 0.6493891151425398

# %%
# Calculer la courbe ROC
fpr, tpr, thresholds = roc_curve(y_true, y_pred)
roc_auc = auc(fpr, tpr)

# Tracer la courbe ROC
plt.figure()
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.savefig("roc_curve.png")
mlflow.log_artifact("roc_curve.png", artifact_path='model')

# %%
mlflow.end_run()
# Out:
# 🏃 View run respected-bass-478 at: https://david-rem-jedha-final-project-mlops.hf.space/#/experiments/2/runs/8aa254acc93640a8ba6a0965c5fdf665
# 🧪 View experiment at: https://david-rem-jedha-final-project-mlops.hf.space/#/experiments/2
